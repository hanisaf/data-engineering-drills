# %% [markdown]
# # Python Review 1 — Drill
# ## Topics: Syntax · Variables · Operators · Scalar Types · Data Structures · Control Flow

# %% [markdown]
# # Exercise 1: Caesar Cipher
#
# A Caesar cipher shifts every letter in a message by a fixed number of positions in the
# alphabet, wrapping around from `z` back to `a`.
#
# ```
# shift = 3
# 'hello' → 'khoor'
# 'xyz'   → 'abc'
# ```
#
# Non-letter characters (spaces, punctuation, digits) are left unchanged.
#
# **Your tasks:**
#
# 1. Write `caesar_encode(text, shift)` that encodes a string.
# 2. Write `caesar_decode(text, shift)` that recovers the original.
# 3. Verify: `caesar_decode(caesar_encode(msg, 13), 13) == msg` for the test messages below.
#
# *Hints:*
# - `ord('a')` → 97, `ord('A')` → 65
# - `chr(n)` converts an integer back to a character
# - `% 26` handles the wrap-around

# %%
# Test messages
messages = [
    "Hello, World!",
    "The quick brown fox jumps over the lazy dog.",
    "Data Engineering 101",
]

# %%
def caesar_encode(text, shift):
    # your code here
    pass

def caesar_decode(text, shift):
    # your code here
    pass

# %%
# Test your functions
for msg in messages:
    encoded = caesar_encode(msg, 13)
    decoded = caesar_decode(encoded, 13)
    print(f"Original : {msg}")
    print(f"Encoded  : {encoded}")
    print(f"Decoded  : {decoded}")
    print(f"Round-trip OK: {decoded == msg}")
    print()

# %% [markdown]
# # Solution

# %% [markdown]
# # Exercise 2: Word Frequency Counter
#
# Below is a short passage of text. Analyse it without using list comprehensions
# (those are in the next session).
#
# **Your tasks:**
#
# 1. **Clean and tokenise** the passage: convert to lowercase, split on whitespace,
#    and strip punctuation from each word.
#    *Hint:* `word.strip('.,!?;:\"'()-')` removes common punctuation at the edges.
#
# 2. **Count frequency**: build a `dict` that maps each word to how many times it appears.
#
# 3. **Top 5 words**: find the 5 most frequent words.
#    *Hint:* `sorted(d.items(), key=...)` with `reverse=True`.
#
# 4. **Hapax legomena**: find all words that appear exactly **once** (classic NLP term).
#
# 5. **Long words**: collect the set of unique words longer than 5 characters.

# %%
passage = """
Python is an easy to learn powerful programming language.
It has efficient high-level data structures and a simple but effective approach
to object-oriented programming. Python's elegant syntax and dynamic typing,
together with its interpreted nature, make it an ideal language for scripting
and rapid application development in many areas on most platforms.
Python is free and runs everywhere. Python is great for data science and
data engineering. Learning Python is a great investment.
"""

# %%
# 1. Clean and tokenise
words = []
# your code here

# 2. Word frequency dict
freq = {}
# your code here

# 3. Top 5 words
top5 = []
# your code here
print("Top 5 words:", top5)

# 4. Hapax legomena (appear exactly once)
hapax = []
# your code here
print("Hapax legomena:", sorted(hapax))

# 5. Long unique words (> 5 characters)
long_words = set()
# your code here
print("Long words:", sorted(long_words))

# %% [markdown]
# # Solution
